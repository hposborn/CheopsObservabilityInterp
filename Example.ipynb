# %%
from astropy.coordinates import SkyCoord
from astropy import units as u
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

import CheopsObservabilityInterp
# Out:
# Matplotlib created a temporary config/cache directory at /var/folders/p0/tmr0j01x4jb3qrbc5b0gnxcw0000gn/T/matplotlib-zjr3988o because the default path (/Users/hosborn/.matplotlib) is not a writable directory; it is highly recommended to set the MPLCONFIGDIR environment variable to a writable directory, in particular to speed up the import of Matplotlib and to better support multiprocessing.

# %%
cheopsRA = np.loadtxt("data/ra_grid.dat")
cheopsDEC = np.loadtxt("data/dec_grid.dat")
cheopsSky = np.loadtxt("data/6am_700_10_noMoon_conf5_V9_50d_49m.dat")

# %%
plt.imshow(cheopsSky)
plt.colorbar()

# %%
data_70 = pd.read_csv("data/70pc_Cheops_Map_data.csv",header=None).values
plt.scatter(data_70[:,0],data_70[:,1],c=data_70[:,2])
plt.colorbar(label="cumulative days at 70% efficiency")

# %%
data_80 = pd.read_csv("data/80pc_Cheops_Map_data.csv",header=None).values
plt.scatter(data_80[:,0],data_80[:,1],c=data_80[:,2])
plt.colorbar(label="cumulative days at 80% efficiency")

# %%
cum_days_obs, n_days_obs, max_eff = CheopsObservabilityInterp.InterpCheopsObs(SkyCoord(217*u.deg,-55*u.deg))
print("This target is observable with Cheops for ~ {:0.1f} days, \nat max efficiency of > {:0.0f} % \nfor a total cumulative time of ~ {:0.1f} days".format(n_days_obs, max_eff,cum_days_obs))
# Out:
# This target is observable with Cheops for ~ 73.4 days,
# at max efficiency of > 50 %
# for a total cumulative time of ~ 44.0 days
